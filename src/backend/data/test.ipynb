# %%
import pickle

with open("IMAGEs.pkl", "rb") as f:
    my_dict = pickle.load(f)
    print(my_dict[1])
    print(len(my_dict))
# Out:
# {'raw': array([[[49, 40, 30],
#         [50, 41, 31],
#         [50, 41, 31],
#         ...,
#         [36, 25, 21],
#         [37, 26, 22],
#         [37, 26, 22]],
#
#        [[49, 40, 30],
#         [49, 40, 30],
#         [50, 41, 31],
#         ...,
#         [37, 26, 22],
#         [38, 27, 23],
#         [38, 27, 23]],
#
#        [[49, 40, 30],
#         [49, 40, 30],
#         [49, 40, 30],
#         ...,
#         [36, 25, 21],
#         [38, 27, 23],
#         [39, 28, 24]],
#
#        ...,
#
#        [[32, 25, 22],
#         [31, 24, 21],
#         [31, 24, 21],
#         ...,
#         [13,  8,  9],
#         [13,  8,  9],
#         [13,  8,  9]],
#
#        [[30, 23, 20],
#         [30, 23, 20],
#         [28, 23, 20],
#         ...,
#         [10,  8,  7],
#         [10,  8,  7],
#         [10,  8,  7]],
#
#        [[29, 22, 19],
#         [28, 23, 20],
#         [28, 23, 20],
#         ...,
#         [12, 10,  9],
#         [12, 10,  9],
# ...
