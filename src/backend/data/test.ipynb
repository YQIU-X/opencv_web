# %%
import pickle

with open("IMAGEs.pkl", "rb") as f:
    my_dict = pickle.load(f)
    print(my_dict[1])
    print(len(my_dict[1]['deque']))
# Out:
# {'current': array([[[40, 28, 22],
#         [41, 27, 21],
#         [41, 27, 21],
#         ...,
#         [41, 28, 23],
#         [40, 28, 24],
#         [42, 29, 24]],
#
#        [[42, 28, 22],
#         [40, 28, 22],
#         [41, 27, 21],
#         ...,
#         [41, 28, 23],
#         [42, 29, 24],
#         [43, 30, 25]],
#
#        [[42, 28, 22],
#         [40, 28, 22],
#         [41, 27, 21],
#         ...,
#         [42, 28, 22],
#         [44, 30, 24],
#         [43, 30, 25]],
#
#        ...,
#
#        [[13, 14, 19],
#         [12, 10, 16],
#         [12, 10, 14],
#         ...,
#         [10,  6,  6],
#         [10,  6,  6],
#         [11,  5,  6]],
#
#        [[10, 11, 18],
#         [12,  8, 16],
#         [10,  9, 11],
#         ...,
#         [13,  7,  8],
#         [12,  6,  8],
#         [12,  6,  8]],
#
#        [[14, 14, 22],
#         [15, 11, 19],
#         [11,  9, 11],
#         ...,
#         [13,  7,  8],
#         [12,  6,  8],
# ...
