# %%
import pickle

with open("IMAGEs.pkl", "rb") as f:
    my_dict = pickle.load(f)
    print(my_dict[1])
    print(len(my_dict[1]['deque']))
# Out:
# {'current': array([[[45, 33, 27],
#         [44, 32, 26],
#         [43, 31, 25],
#         ...,
#         [43, 31, 27],
#         [45, 33, 29],
#         [44, 32, 28]],
#
#        [[43, 31, 25],
#         [43, 31, 25],
#         [42, 30, 24],
#         ...,
#         [43, 31, 25],
#         [46, 34, 28],
#         [45, 33, 29]],
#
#        [[44, 32, 26],
#         [43, 31, 25],
#         [42, 30, 24],
#         ...,
#         [43, 31, 25],
#         [48, 34, 28],
#         [48, 34, 28]],
#
#        ...,
#
#        [[ 8,  3, 12],
#         [16, 19, 23],
#         [15, 10, 12],
#         ...,
#         [18, 13, 12],
#         [12,  7,  6],
#         [11,  6,  8]],
#
#        [[28, 24, 36],
#         [20, 24, 29],
#         [16, 11, 12],
#         ...,
#         [ 7,  3,  2],
#         [17, 12, 13],
#         [16,  9, 12]],
#
#        [[12,  7, 22],
#         [ 1,  5, 10],
#         [10,  6,  5],
#         ...,
#         [15, 10, 11],
#         [11,  6,  8],
# ...
